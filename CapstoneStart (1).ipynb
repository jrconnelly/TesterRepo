# %% [markdown]
# This file is the beginning of the capstone project for the IBM Data Science Certification module 9. First instruction was to create a github repository, clone it and populate with a sample file. THis involved creating an RSA key for authentication. Now we are creating the jupyter notebook to execute some commands. To start with the first one is
# print (" Hello Capstone Project Course")

# %%
print (" Hello Capstone Project Course")
import pandas as pd
import numpy as np
import requests # library to handle requests
import urllib.request # scraper from tutorial 
# warning easyinstall will be removed in future version
# !easy_install beautifulsoup4
# !pip install lxml # one parser
#!apt-get install python-lxml #another parser
# !conda install -c conda-forge folium=0.5.0 --yes
from bs4 import BeautifulSoup
### forum for foursquare
#%capture
#!pip install geocoder
# Out:
#  Hello Capstone Project Course
# WARNING: The easy_install command is deprecated and will be removed in a future version.
# Searching for beautifulsoup4
# Reading https://pypi.org/simple/beautifulsoup4/
# ...
# Best match: beautifulsoup4 4.9.0
# Processing beautifulsoup4-4.9.0-py3-none-any.whl
# Installing beautifulsoup4-4.9.0-py3-none-any.whl to /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages
# Adding beautifulsoup4 4.9.0 to easy-install.pth file
#
# Installed /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/beautifulsoup4-4.9.0-py3.6.egg
# Processing dependencies for beautifulsoup4
# Searching for soupsieve>1.2
# Reading https://pypi.org/simple/soupsieve/
# ...
# Best match: soupsieve 2.0.1
# Processing soupsieve-2.0.1-py3-none-any.whl
# Installing soupsieve-2.0.1-py3-none-any.whl to /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages
# Adding soupsieve 2.0.1 to easy-install.pth file
#
# ...

# %%
 # COMMENT UNCOMMENT for READTHIS PART WORKS------------------------------------##
df_latlon = pd.read_csv('http://cocl.us/Geospatial_data')
df_latlon.head()
df_latlon.rename(columns={'Postal Code':'PostalCode'},inplace=True)
df_latlon['PostalCode']
# This works end -----------------
# Out:
# 0      M1B
# 1      M1C
# 2      M1E
# 3      M1G
# 4      M1H
#       ...
# 98     M9N
# 99     M9P
# 100    M9R
# 101    M9V
# 102    M9W
# Name: PostalCode, Length: 103, dtype: object

# %%
# BEAUTIFUL SOup BLOCK Try - first worked with bs4 import then same command didn't work next day
#https://simpleanalytical.com/how-to-web-scrape-wikipedia-python-urllib-beautiful-soup-pandas
#https://beautiful-soup-4.readthedocs.io/en/latest/
# Request given page for data

#soup = BeautifulSoup(content,"html.parser")
#print(soup)
#wikitable = soup.find('table', class_='wikitable sortable')
#print(wikitable)
# This worked once
# from forum for caputring tags
#l = []
#for tr in table_rows:
#    td = tr.find_all('td')
#    row = [tr.text for tr in td]
#    l.append(row)
#pd.DataFrame(l, columns=["A", "B", ...])
## example from forum to capture ----------
#df_new=df[df['column-name'] != 'Not Assigned']
# 
#df[df['Borough'].astype(str).str.contains('your_variable')]
## MORE USELESS HELP BUT HERE IT IS
#import pandas as pd
#import requests
#from bs4 import BeautifulSoup
#req = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")
#soup = BeautifulSoup(req.content,'lxml')
#table = soup.find_all('table')[0]

# %%
#This  request for data provided works begin =================
#url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
#from bs4 import BeautifulSoup
#req = requests.get(url)
#table = req.content
#df = pd.read_html(str(table))
#neighborhood=pd.DataFrame(df[0])
## this works end ===============
# Clean up column names, remove \n
# This works -------begin
#df.rename(columns={'Postal Code':'PostalCode'},inplace=True)
#add regular expressions to import resources
import pandas as pd
import re
# line below works before processing below but not after
#neighborhood=pd.DataFrame(df[0])
#neighborhood.rename(columns={'Postal Code\\n':'PostalCode'},inplace=True)
neighborhood.rename(columns={'Borough\\n':'Borough'},inplace=True)
neighborhood.rename(columns={'Postal Code\\n':'PostalCode'},inplace=True)
neighborhood.rename(columns={'Neighborhood\\n':'Neighborhood'},inplace=True)
neighborhood.Borough
neighborhood.PostalCode
neighborhood
df_latlon.shape
neighborhood.shape
#neighborhood.shape
#df = neighborhood
#df

# %%
# try to merge
# create 3rd data frame

pd.merge(df_latlon, neighborhood, on='PostalCode')
#pd.merge(df_new, df_n, left_on='subject_id', right_on='subject_id')
#geo_merged = pd.merge(df_latlon,neighborhood)
#geo_merged
# remove Not assigned entries works
#neighborhood.Borough != 'Not assigned'
#replace Not assigned with NaN works
#df = neighborhood.Borough.replace("Not assigned\\n","NaN")
#neighborhood.Borough.replace("\\n"," ")
# Not sure about below
#neighborhood1 = neighborhood.Borough.replace("*\\n","*")
#df = neighborhood1
#df[df.Borough != 'NaN']
#df.shape
#df = df[df.Borough == "NaN"]
#geo_dump = pd.DataFrame(raw_data, columns = ['subject_id','test_id'])
#pd.concat([df_a, df_b], axis=1)
# Out:
# Empty DataFrame
# Columns: [PostalCode, Latitude, Longitude, Borough, Neighborhood]
# Index: []

# %% [markdown]
# ### working area ------
# #df[!grepl("NaN", df$Name),]
# #remove strings
# #df[~df.dates.str.contains('/')]
# #
# #https://simpleanalytical.com/how-to-web-scrape-wikipedia-python-urllib-beautiful-soup-pandas
# #https://beautiful-soup-4.readthedocs.io/en/latest/
# # Request given page for data
# url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
# #page = urllib.request.urlopen(url)
# #READ in DATA
# headers = ["Postal Code","Borough","Neighborhood"]
# filename = "http://en.wikipedia.org/w/index.php?title=List_of_postal_codes_of_Canada:_M&direction=prev&oldid=92628764"
# #dflist_postal = pd.read_html('https://en.wikipedia.org/w/index.php?title=List_of_postal_codes_of_Canada:_M&direction=prev&oldid=926287641')
# dflist_postal = pd.read_html(url, header=0)
# dflist_postal[0].head
# #
# # good way to show how data is not what you think
# #
# dframe_postal = pd.array(dflist_postal)
# ## takes first 3 columns
# #df3=dframe_postal[::4]
# #df4=df3[::1]
# #df4
# #
# #df = dframe_postal.ndim
# #dframe_postal
# #dframe_postal = np.array(dflist_postal)
# #df = dframe_postal.ndim
# #dframe_postal
# #
# #dframe_postal.loc['Borough']
# #from video week 2 data analysis with python
# #dframe_postal["Borough"].replace("Not assigned",nan)
# #dflist_postal["Borough" != 'Not assigned']
#
# #df[df.name != 'Tina']
#
# #dframe_postal
# #dframe_postal.shape
# #dframe_postal
# #df[dframe_postal() != 'Tina']
# #dflist_postal
# #dframe_postal[dframe_postal(1) == 'Not assigned']
#
# #pd.isnull(dframe_postal)
# #dflist_postal[:3]
# #df[dframe_postal.Borough == 'Not assigned']
# #df = pd.DataFrame(dframe_postal.Borough, index = ???)
# #dframe_postal.dtypes()
#
# #dframe_postal.drop_duplicates()
# #
# #OK from here
# # we need folium for get geo boundaries
#
# #import folium # plotting library
# # define the world map centered around our coordinates of interest with a low zoom level
# ## OK from here
# #toronto_map = folium.Map(location=[43.806686, -79.194353], zoom_start=12)
# # display map of interest
# #toronto_map

# %% [markdown]
# # Read in data file provided in lab materials with geo data
# # we want to build dataframe of the postal code of each neighborhood along with the borough name and neighborhood name,
# # in order to utilize the Foursquare location data, we need to get the latitude and the longitude coordinates of each neighborhood.
# # We also use Fourswaure to get the neighborhood names so my credientials are included
#
# #CLIENT_ID = 'V3R4GWWHBFL23A4OEPUFIUX3XRT2GICELQSPXRHJ1DAS0C2A' # your Foursquare ID
# #CLIENT_SECRET = 'WMLA0CKK2CTN2F1D0GBGSKN00EVX5LL4ZLQZSPYJZIOTEEPE' # your Foursquare Secret
# #VERSION = '20180604'
# #LIMIT = 30
# #print('Your credentails:')
# #print('CLIENT_ID: ' + CLIENT_ID)
# #print('CLIENT_SECRET:' + CLIENT_SECRET)
# #
# # This request gathers only the Postal coe and lat/lon. We also want neighborhood and boroughs so we center the foursquare request on
# # the lat/lon  of one namely start with 0	M1B	43.806686	-79.194353
# #
# #Use the Notebook to build the code to scrape the following Wikipedia page,
# # https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M, in order to obtain the
# # data that is in the table of postal codes and to transform the data into a pandas dataframe
# # COMMENT UNCOMMENT for read THIS PART WORKS------------------------------------##
# #df_latlon = pd.read_csv('http://cocl.us/Geospatial_data')
# df_latlon.head()
# df_latlon.rename(columns={'Postal Code':'PostalCode'},inplace=True)
# df_latlon
# # sample to combine from forum
# #geo_merged = pd.merge(df_latlon,df_merge, on=PostalCode)
#
# # now need to define df_merge  - this will be from the wiki page scrape----------##
#
# #columns = ["Postal Code","Boroughs", "Neighborhood"]
# #
# # use first row as header
# # COMMENT UNCOMMENT for read------------------------------------##
# #list_postal = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M', header = 0)
# #list_postal[0].head
# #
# # make into array
# #
# #df_postal = np.array(list_postal)
# #df_postal.loc[df_postal['Borough'] == "Not Assigned"]
#
# #
# # sample to clean from data wrangling lab
# #import numpy as np
# # replace "?" to NaN
# #df.replace("?", np.nan, inplace = True)
# #df.head(5)
# # need to drop row for nan check how
# #
# #latitude = 43.806686
# #longitude = -79.19435
# #radius = 500
# #LIMIT = 100
# #search_query = ''
# #url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
# #url
# #results = requests.get(url).json()
# #results
# #venues = results['Borough']['Neighborhood']
#
# #list_postal.replace("Not Assigned", REMOVE, inplace=True)
# #df_postal.replace("Not assigned", "REMOVE", inplace=True)
# #list_postal.sort_values(['Postal Code'], ascending=False, axis=1, inplace=True)

# %%
dframe_postal.shape
# Out:
# (3,)

# %% [markdown]
# ## ffrom lab 3-3-2 segmenting or later after scraping
# # define the dataframe columns
# column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude']
#
# # instantiate the dataframe
# neighborhoods = pd.DataFrame(columns=column_names)
# for data in neighborhoods_data:
#     borough = neighborhood_name = data['properties']['borough']
#     neighborhood_name = data['properties']['name']
#
#     neighborhood_latlon = data['geometry']['coordinates']
#     neighborhood_lat = neighborhood_latlon[1]
#     neighborhood_lon = neighborhood_latlon[0]
#
#     neighborhoods = neighborhoods.append({'Borough': borough,
#                                           'Neighborhood': neighborhood_name,
#                                           'Latitude': neighborhood_lat,
#                                           'Longitude': neighborhood_lon}, ignore_index=True)
#     print('The dataframe has {} boroughs and {} neighborhoods.'.format(
#         len(neighborhoods['Borough'].unique()),
#         neighborhoods.shape[0]
#     )
# )

# %%
#help ( urllib.request)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-19-ad02c0465440> in <module>
#       1 #help ( urllib.request)
#       2 df_latlon
# ----> 3 list_postal = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M', header = 0)
#       4 list_postal[0].head
#
# ~/conda/envs/python/lib/python3.6/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1098         na_values=na_values,
#    1099         keep_default_na=keep_default_na,
# -> 1100         displayed_only=displayed_only,
#    1101     )
#
# ~/conda/envs/python/lib/python3.6/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     889     retained = None
#     890     for flav in flavor:
# ...

# %%
help ()
# Out:
# Welcome to Python 3.6's help utility!
#
# If this is your first time using Python, you should definitely check out
# the tutorial on the Internet at https://docs.python.org/3.6/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To quit this help utility and
# return to the interpreter, just type "quit".
#
# To get a list of available modules, keywords, symbols, or topics, type
# "modules", "keywords", "symbols", or "topics".  Each module also comes
# with a one-line summary of what it does; to list the modules whose name
# or summary contain a given string such as "spam", type "modules spam".
# help>  drop row
# No Python documentation found for 'drop row'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.
# help>  help(df.dropna)
# No Python documentation found for 'help(df.dropna)'.
# Use help() to get the interactive help utility.
# ...
